# %%
import pandas as pd

# Definir o caminho para o arquivo CSV
csv_file_path = r'D:/OneDrive - InMotion - Consulting/AI Projects/AI-Clinical-Advisory-Crew/DB/consolidated_patient_feedback.csv' 


# Ler o CSV, ignorando linhas problemáticas
df = pd.read_csv(csv_file_path, on_bad_lines='skip')

# Contar as linhas vazias em cada coluna
empty_counts = df.isnull().sum()

# Contar as linhas não vazias em cada coluna
non_empty_counts = df.notnull().sum()

# Criar um DataFrame com a contagem de linhas vazias e não vazias
counts_df = pd.DataFrame({
    'Column': df.columns,
    'Non_Empty_Count': non_empty_counts,
    'Empty_Count': empty_counts
})

# Exibir a tabela com a contagem de linhas vazias e não vazias
print("Contagem de linhas vazias e não vazias em cada coluna:")
print(counts_df)
# Out:
# Contagem de linhas vazias e não vazias em cada coluna:
#                                                                                                Column  \
# Feedback_ID                                                                               Feedback_ID
# Total_execution_time                                                             Total_execution_time
# Patient_Feedback                                                                     Patient_Feedback
# Sentiment_Patient_Experience_Expert                               Sentiment_Patient_Experience_Expert
# Emotional_Intensity_Patient_Experience_Expert           Emotional_Intensity_Patient_Experience_Expert
# Urgency_Level_Patient_Experience_Expert                       Urgency_Level_Patient_Experience_Expert
# Key_Issues_Patient_Experience_Expert                             Key_Issues_Patient_Experience_Expert
# Patient_Journey_Health_IT_Process_Expert                     Patient_Journey_Health_IT_Process_Expert
# Inefficiencies_Healthcare_Process_Health_IT_Pro...  Inefficiencies_Healthcare_Process_Health_IT_Pr...
# Improvement_Suggestions_Healthcare_Process_Heal...  Improvement_Suggestions_Healthcare_Process_Hea...
# Emotional_State_Clinical_Psychologist                           Emotional_State_Clinical_Psychologist
# Support_Strategy_Clinical_Psychologist                         Support_Strategy_Clinical_Psychologist
# Suggested_Approach_Clinical_Psychologist                     Suggested_Approach_Clinical_Psychologist
# Communication_Quality_Communication_Expert                 Communication_Quality_Communication_Expert
# Issues_Identified_Communication_Expert                         Issues_Identified_Communication_Expert
# Suggested_Improvements_Communication_Expert               Suggested_Improvements_Communication_Expert
# Final_Recommendation_Communication_Expert                   Final_Recommendation_Communication_Expert
# Key_Issues_Manager_and_Advisor                                         Key_Issues_Manager_and_Advisor
# Recommendations_Manager_and_Advisor                               Recommendations_Manager_and_Advisor
#
#                                                     Non_Empty_Count  \
# Feedback_ID                                                      12
# Total_execution_time                                             12
# Patient_Feedback                                                 12
# Sentiment_Patient_Experience_Expert                              12
# Emotional_Intensity_Patient_Experience_Expert                    12
# Urgency_Level_Patient_Experience_Expert                          12
# Key_Issues_Patient_Experience_Expert                             12
# Patient_Journey_Health_IT_Process_Expert                          0
# Inefficiencies_Healthcare_Process_Health_IT_Pro...                0
# Improvement_Suggestions_Healthcare_Process_Heal...                0
# Emotional_State_Clinical_Psychologist                            12
# Support_Strategy_Clinical_Psychologist                           12
# Suggested_Approach_Clinical_Psychologist                         12
# Communication_Quality_Communication_Expert                       12
# Issues_Identified_Communication_Expert                           12
# Suggested_Improvements_Communication_Expert                      12
# Final_Recommendation_Communication_Expert                        12
# Key_Issues_Manager_and_Advisor                                   12
# Recommendations_Manager_and_Advisor                              12
#
#                                                     Empty_Count
# Feedback_ID                                                   0
# Total_execution_time                                          0
# Patient_Feedback                                              0
# Sentiment_Patient_Experience_Expert                           0
# Emotional_Intensity_Patient_Experience_Expert                 0
# Urgency_Level_Patient_Experience_Expert                       0
# Key_Issues_Patient_Experience_Expert                          0
# Patient_Journey_Health_IT_Process_Expert                     12
# Inefficiencies_Healthcare_Process_Health_IT_Pro...           12
# Improvement_Suggestions_Healthcare_Process_Heal...           12
# Emotional_State_Clinical_Psychologist                         0
# Support_Strategy_Clinical_Psychologist                        0
# Suggested_Approach_Clinical_Psychologist                      0
# Communication_Quality_Communication_Expert                    0
# Issues_Identified_Communication_Expert                        0
# Suggested_Improvements_Communication_Expert                   0
# Final_Recommendation_Communication_Expert                     0
# Key_Issues_Manager_and_Advisor                                0
# Recommendations_Manager_and_Advisor                           0

# %%
import pandas as pd

# Definir o caminho para o arquivo CSV
csv_file_path = r'D:/OneDrive - InMotion - Consulting/AI Projects/AI-Clinical-Advisory-Crew/DB/consolidated_patient_feedback.csv' 

# Ler o CSV
df = pd.read_csv(csv_file_path)

# Exibir as primeiras linhas do dataframe para visualizar os dados
df.head(20)
# Out:
#               Feedback_ID      Total_execution_time  \
# 0  report_20240924_011048  3 minutes and 54 seconds
# 1  report_20240924_011805  3 minutes and 16 seconds
# 2  report_20240924_012150  3 minutes and 12 seconds
# 3  report_20240924_012512   3 minutes and 2 seconds
# 4  report_20240924_012913   3 minutes and 4 seconds
# 5  report_20240924_013315  3 minutes and 41 seconds
# 6  report_20240924_013704  3 minutes and 11 seconds
# 7  report_20240924_014059  3 minutes and 31 seconds
#
#                                     Patient_Feedback  \
# 0  He works at the Santo Amaro rehabilitation cen...
# 1  Catastrophe since Fr. Dr. Sommerfeld is no lon...
# 2  Expensive, unfriendly and you couldn't make ap...
# 3  Expensive, unfriendly and you couldn't make ap...
# 4  Catastrophe since Fr. Dr. Sommerfeld is no lon...
# 5  Catastrophe since Fr. Dr. Sommerfeld is no lon...
# 6  Another patient and I waited for authorization...
# 7  It was scheduled for 2:50 pm, and I was seen a...
#
#   Sentiment_Patient_Experience_Expert  \
# 0                            Negative
# 1                            Negative
# 2                            Negative
# 3                            Negative
# 4                            Negative
# 5                            Negative
# 6                            Negative
# 7                            Negative
#
#        Emotional_Intensity_Patient_Experience_Expert  \
# 0  -0.9 (High negative sentiment due to phrases l...
# 1  -0.85 (indicating a high level of negative emo...
# 2                                              -0.85
# 3                                              -0.85
# 4                     -0.9 (High negative sentiment)
# 5                             -0.9 (Highly negative)
# 6                                               -0.7
# 7  -0.8 (High negative emotion due to frustration...
#
#              Urgency_Level_Patient_Experience_Expert  \
# 0  High (Phrases like "very difficult", "bad expe...
# 1  High (due to the patient's repeated negative e...
# 2                                               High
# 3                                               High
# 4  High (Patient experienced immediate distress a...
# 5                                               High
# 6                                             Medium
# 7  Medium (The issue is ongoing as the patient fe...
#
#                 Key_Issues_Patient_Experience_Expert  \
# 0  Key_Issues_Patient_Experience_Expert:; Lack of...
# 1  Key_Issues_Patient_Experience_Expert:; **Staff...
# 2  Key_Issues_Patient_Experience_Expert:; Financi...
# 3              Key_Issues_Patient_Experience_Expert:
# 4  Key_Issues_Patient_Experience_Expert:; Incompe...
# 5  Key_Issues_Patient_Experience_Expert:; Lack of...
# 6  Key_Issues_Patient_Experience_Expert:; Lack of...
# 7  Key_Issues_Patient_Experience_Expert:; Delays ...
#
#    Patient_Journey_Health_IT_Process_Expert  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
#
#    Inefficiencies_Healthcare_Process_Health_IT_Process_Expert  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    Improvement_Suggestions_Healthcare_Process_Health_IT_Process_Expert  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#                Emotional_State_Clinical_Psychologist  \
# 0  The patient expresses feelings of frustration,...
# 1  The patient expresses feelings of anger, frust...
# 2  The patient expresses feelings of frustration,...
# 3  The patient likely feels angry, frustrated, an...
# 4  The patient expresses feelings of frustration,...
# 5  The patient expresses feelings of frustration,...
# 6  Frustration, disappointment, and possibly ange...
# 7  The patient expresses feelings of frustration,...
#
#               Support_Strategy_Clinical_Psychologist  \
# 0  A supportive and empathetic approach is crucia...
# 1  Validate the patient's feelings by actively li...
# 2  Validate the patient's emotions, emphasizing t...
# 3  Validate the patient's feelings and acknowledg...
# 4  A supportive therapeutic approach is needed, f...
# 5  Validation of the patient's feelings is crucia...
# 6  Validate the patient's feelings, acknowledging...
# 7  A patient-centered approach focusing on valida...
#
#             Suggested_Approach_Clinical_Psychologist  \
# 0  Suggested_Approach_Clinical_Psychologist:; Beg...
# 1  Suggested_Approach_Clinical_Psychologist:; Hel...
# 2  Suggested_Approach_Clinical_Psychologist:; Hel...
# 3  Suggested_Approach_Clinical_Psychologist:; Enc...
# 4  Suggested_Approach_Clinical_Psychologist:; Beg...
# 5  Suggested_Approach_Clinical_Psychologist:; Ack...
# 6  Suggested_Approach_Clinical_Psychologist:; Act...
# 7  Suggested_Approach_Clinical_Psychologist:; Beg...
#
#   Communication_Quality_Communication_Expert  \
# 0                                       Poor
# 1                                       Poor
# 2                                       Poor
# 3                                       Poor
# 4                                       Poor
# 5                                       Poor
# 6                                       Poor
# 7                                       Poor
#
#               Issues_Identified_Communication_Expert  \
# 0  Issues_Identified_Communication_Expert:; Lack ...
# 1  Issues_Identified_Communication_Expert:; Lack ...
# 2  Issues_Identified_Communication_Expert:; Lack ...
# 3  Issues_Identified_Communication_Expert:; Lack ...
# 4  Issues_Identified_Communication_Expert:; Dismi...
# 5  Issues_Identified_Communication_Expert:; Lack ...
# 6  Issues_Identified_Communication_Expert:; Lack ...
# 7  Issues_Identified_Communication_Expert:; Lack ...
#
#     Suggested_Improvements_Communication_Expert  \
# 0  Suggested_Improvements_Communication_Expert:
# 1  Suggested_Improvements_Communication_Expert:
# 2  Suggested_Improvements_Communication_Expert:
# 3  Suggested_Improvements_Communication_Expert:
# 4  Suggested_Improvements_Communication_Expert:
# 5  Suggested_Improvements_Communication_Expert:
# 6  Suggested_Improvements_Communication_Expert:
# 7  Suggested_Improvements_Communication_Expert:
#
#            Final_Recommendation_Communication_Expert  \
# 0  The rehabilitation center must prioritize impl...
# 1  The practice urgently needs to address these c...
# 2  The orthodontic practice should prioritize ope...
# 3  Prioritize patient-centered communication by f...
# 4  A comprehensive review of the practice's commu...
# 5  A comprehensive overhaul of the practice's com...
# 6  Develop and implement a comprehensive communic...
# 7  A comprehensive training program for healthcar...
#
#                       Key_Issues_Manager_and_Advisor  \
# 0  Key_Issues_Manager_and_Advisor:; Lack of aware...
# 1  Key_Issues_Manager_and_Advisor:; Lack of profe...
# 2  Key_Issues_Manager_and_Advisor:; Lack of empat...
# 3  Key_Issues_Manager_and_Advisor:; Lack of empat...
# 4  Key_Issues_Manager_and_Advisor:; Dismissive an...
# 5  Key_Issues_Manager_and_Advisor:; Lack of respe...
# 6  Key_Issues_Manager_and_Advisor:; Lack of commu...
# 7  Key_Issues_Manager_and_Advisor:; Lack of empat...
#
#     Recommendations_Manager_and_Advisor
# 0  Recommendations_Manager_and_Advisor:
# 1  Recommendations_Manager_and_Advisor:
# 2  Recommendations_Manager_and_Advisor:
# 3  Recommendations_Manager_and_Advisor:
# 4  Recommendations_Manager_and_Advisor:
# 5  Recommendations_Manager_and_Advisor:
# 6  Recommendations_Manager_and_Advisor:
# 7  Recommendations_Manager_and_Advisor:
