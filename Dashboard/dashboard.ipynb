# %%
import pandas as pd

# Definir o caminho para o arquivo CSV
csv_file_path = r'D:/OneDrive - InMotion - Consulting/AI Projects/AI-Clinical-Advisory-Crew/Dashboard/processed_patient_feedback.csv'

# Ler o CSV
df = pd.read_csv(csv_file_path)

# Exibir as primeiras linhas do dataframe para visualizar os dados
df.head()
# Out:
#               Feedback_ID       Total_execution_time  \
# 0  report_20240923_120254  4 minutes and 19 seconds.
# 1  report_20240923_121101  3 minutes and 27 seconds.
# 2  report_20240923_122302  3 minutes and 55 seconds.
# 3  report_20240923_122854  4 minutes and 28 seconds.
# 4  report_20240923_123427  4 minutes and 57 seconds.
#
#                                     Patient_Feedback  \
# 0  I went with great expectations, but I felt tha...
# 1  Doctor made me wait more than two hours for th...
# 2  The attendant did not inform us that the docto...
# 3  This psychologist canceled the 1st appointment...
# 4  I consulted the UNIMED website and found the I...
#
#                  Sentiment_Patient_Experience_Expert  \
# 0                                           Negative
# 1                                           Negative
# 2  Negative (Expresses clear dissatisfaction and ...
# 3                                           Negative
# 4                                           Negative
#
#        Emotional_Intensity_Patient_Experience_Expert  \
# 0                               -0.8 (Very negative)
# 1                                 -1 (very negative)
# 2  -0.8 (Very negative, indicating strong dissati...
# 3                               -0.9 (very negative)
# 4                               -0.9 (Very negative)
#
#              Urgency_Level_Patient_Experience_Expert  \
# 0                                               High
# 1                                               High
# 2  High (Immediate action is required to address ...
# 3                                               High
# 4                                               High
#
#                 Key_Issues_Patient_Experience_Expert  \
# 0  Lack of attentive and investigative approach f...
# 1  Issue 1: Excessive waiting time for appointmen...
# 2  Issue 1: Inadequate communication regarding do...
# 3  Issue 1: The psychologist canceled the first a...
# 4  Issue 1: Confusion regarding insurance coverag...
#
#    Patient_Journey_Health_IT_Process_Expert  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Inefficiencies_Healthcare_Process_Health_IT_Process_Expert  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Improvement_Suggestions_Healthcare_Process_Health_IT_Process_Expert  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3          their practices based on patient insights
# 4  their skills in handling customer inquiries an...
#
#                Emotional_State_Clinical_Psychologist  \
# 0  The patient is experiencing a complex mix of n...
# 1  The patient expresses feelings of **frustratio...
# 2  The patient expresses feelings of **frustratio...
# 3  The patient expresses feelings of **disappoint...
# 4  The patient expresses feelings of **frustratio...
#
#               Support_Strategy_Clinical_Psychologist  \
# 0  To address these emotions, a multi-pronged sup...
# 1  Acknowledge and validate the patient's feeling...
# 2  Validate the patient's feelings by acknowledgi...
# 3  A tailored strategy should focus on rebuilding...
# 4  To address these emotions, a strategy focused ...
#
#             Suggested_Approach_Clinical_Psychologist  \
# 0  1. **Compassionate Listening:** Begin by activ...
# 1  1. **Active Listening:** Begin by attentively ...
# 2  1. **Active Listening:** Begin by actively lis...
# 3  A collaborative approach is crucial. Start by ...
# 4  1. **Active Listening and Validation:** Begin ...
#
#   Communication_Quality_Communication_Expert  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Issues_Identified_Communication_Expert  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#          Suggested_Improvements_Communication_Expert  \
# 0                                                NaN
# 1                                                NaN
# 2  Centered Rescheduling:** Offer patients multip...
# 3                                                NaN
# 4                                                NaN
#
#            Final_Recommendation_Communication_Expert  \
# 0                                                NaN
# 1                                                NaN
# 2  To significantly improve communication quality...
# 3                                                NaN
# 4                                                NaN
#
#   Key_Issues_Manager_and_Advisor Recommendations_Manager_and_Advisor
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                            NaN                                 NaN
# 4                            NaN                                 NaN
