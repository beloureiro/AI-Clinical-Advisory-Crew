# %%
import pandas as pd

# Definir o caminho para o arquivo CSV
csv_file_path = r'D:/OneDrive - InMotion - Consulting/AI Projects/AI-Clinical-Advisory-Crew/Dashboard/processed_patient_feedback.csv'

# Ler o CSV
df = pd.read_csv(csv_file_path)

# Exibir as primeiras linhas do dataframe para visualizar os dados
df.head(20)
# Out:
#                Feedback_ID       Total_execution_time  \
# 0   report_20240923_214557  3 minutes and 18 seconds.
# 1   report_20240923_220640  2 minutes and 59 seconds.
# 2   report_20240923_222753  3 minutes and 30 seconds.
# 3   report_20240923_223218  3 minutes and 53 seconds.
# 4   report_20240923_223636  3 minutes and 49 seconds.
# 5   report_20240923_224040  3 minutes and 39 seconds.
# 6   report_20240923_224442  3 minutes and 32 seconds.
# 7   report_20240923_224848  3 minutes and 24 seconds.
# 8   report_20240923_225332  4 minutes and 19 seconds.
# 9   report_20240923_225806   4 minutes and 9 seconds.
# 10  report_20240923_230241   4 minutes and 8 seconds.
# 11  report_20240923_230647  3 minutes and 41 seconds.
#
#                                      Patient_Feedback  \
# 0   The doctor will not continue the treatment wit...
# 1   Despite acute pain in my knee, I was turned aw...
# 2   Very unfriendly. I don't normally give reviews...
# 3   The secretary sucks. Very rude hung up on my f...
# 4   It was my second colonoscopy for cancer preven...
# 5   NEVER AGAIN! I don't criticize the doctor hims...
# 6   NEVER AGAIN! I don't criticize the doctor hims...
# 7   NEVER AGAIN! I don't criticize the doctor hims...
# 8   If you are esoteric, therapy is recommended. B...
# 9   Despite an appointment, I had to wait 3 hours ...
# 10  I am very disappointed, something like this ha...
# 11  I am very disappointed, something like this ha...
#
#    Sentiment_Patient_Experience_Expert  \
# 0                             Negative
# 1                             Negative
# 2                             Negative
# 3                             Negative
# 4                             Negative
# 5                             Negative
# 6                             Negative
# 7                             Negative
# 8                             Negative
# 9                             Negative
# 10                            Negative
# 11                            Negative
#
#     Emotional_Intensity_Patient_Experience_Expert  \
# 0                                           -0.85
# 1                                           -0.80
# 2                                           -0.95
# 3                                           -0.90
# 4                                           -0.60
# 5                                           -0.80
# 6                                           -0.80
# 7                                           -0.90
# 8                                           -0.90
# 9                                           -0.80
# 10                                          -0.90
# 11                                          -0.95
#
#    Urgency_Level_Patient_Experience_Expert  \
# 0                                     High
# 1                                     High
# 2                                     High
# 3                                     High
# 4                                     High
# 5                                     High
# 6                                     High
# 7                                     High
# 8                                     High
# 9                                   Medium
# 10                                    High
# 11                                    High
#
#                  Key_Issues_Patient_Experience_Expert  \
# 0   - Lack of communication regarding treatment di...
# 1   - Lack of immediate attention for acute pain d...
# 2   - Unfriendly and unprofessional staff behavior...
# 3   - Secretary's rude behavior and abrupt termina...
# 4   - Pain and discomfort during and after the col...
# 5   - Lack of empathy and unprofessionalism at rec...
# 6   - Delays and resistance at reception despite e...
# 7   - Initial refusal and lack of trust in patient...
# 8   - The therapist's inappropriate self-disclosur...
# 9                                                 NaN
# 10  - Doctor dismissed patient's concerns and ende...
# 11  - Doctor's short consultation time and dismiss...
#
#              Patient_Journey_Health_IT_Process_Expert  \
# 0   The patient began by contacting healthcare pro...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   - Arrived for appointment, expected immediate ...
# 10  The patient arrived at the healthcare facility...
# 11                                                NaN
#
#    Inefficiencies_Healthcare_Process_Health_IT_Process_Expert  \
# 0   - Failure in timely and effective communicatio...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Inefficient time management resulted in insuff...
# 11                                                NaN
#
#    Improvement_Suggestions_Healthcare_Process_Health_IT_Process_Expert  \
# 0   - Introduce a multi-channel communication syst...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   1. Implement a dedicated emergency protocol wi...
# 8                                                 NaN
# 9   - Implement dynamic scheduling algorithms that...
# 10  To address these issues, the healthcare provid...
# 11                                                NaN
#
#                 Emotional_State_Clinical_Psychologist  \
# 0   The patient exhibits symptoms of anger, frustr...
# 1   The patient expresses feelings of frustration,...
# 2   The patient expresses profound anger, hurt, an...
# 3   The patient expresses anger, frustration, and ...
# 4   The patient is experiencing a range of negativ...
# 5   The patient is experiencing a range of intense...
# 6   The patient expresses feelings of anger, frust...
# 7   The patient expresses feelings of anger, frust...
# 8   The patient is experiencing feelings of discom...
# 9   The patient expresses feelings of frustration,...
# 10  The patient is experiencing profound disappoin...
# 11  The patient is experiencing a complex mix of e...
#
#                Support_Strategy_Clinical_Psychologist  \
# 0   A supportive and empathetic approach is crucia...
# 1   The patient needs validation for their feeling...
# 2   To address this emotional state, validation is...
# 3   Validate the patient's feelings, acknowledge t...
# 4   Validate the patient's feelings, acknowledging...
# 5   A supportive approach centered on validating t...
# 6   Validate the patient's feelings and acknowledg...
# 7   Validate the patient's feelings, acknowledge t...
# 8   The primary focus should be on validating the ...
# 9   Validate the patient's feelings, acknowledging...
# 10  Validation and normalization of the patient's ...
# 11  A primary focus should be on validating the pa...
#
#              Suggested_Approach_Clinical_Psychologist  \
# 0   - Begin by acknowledging and validating the pa...
# 1   - Help the patient express their anger and fru...
# 2   - Begin by validating their feelings and expre...
# 3                                                 NaN
# 4   - Help the patient identify their most pressin...
# 5   - Active listening and empathetic validation o...
# 6   - Begin by actively listening to the patient's...
# 7   - Encourage the patient to express their emoti...
# 8   - Help the patient process their emotional dis...
# 9   - Help the patient identify their specific con...
# 10  - Actively listen to the patient's account, ac...
# 11  - Begin by expressing empathy for the patient'...
#
#    Communication_Quality_Communication_Expert  \
# 0                                        Poor
# 1                                        Poor
# 2                                        Poor
# 3                                        Poor
# 4                                        Poor
# 5                                        Poor
# 6                                        Poor
# 7                                        Poor
# 8                                        Poor
# 9                                        Poor
# 10                                       Poor
# 11                                       Poor
#
#                Issues_Identified_Communication_Expert  \
# 0   - Lack of responsiveness to patient inquiries....
# 1   - Unequal treatment based on insurance status....
# 2   - Unfriendly and unempathetic behavior\n- Lack...
# 3   - Rudeness and dismissiveness from the secreta...
# 4   - Painful procedure and ongoing digestive issu...
# 5   - Lack of empathy and compassion from receptio...
# 6   - Lack of empathy and unprofessional conduct f...
# 7   - Lack of empathy and compassion from receptio...
# 8                                                 NaN
# 9   - Extremely long wait times (3 hours) leading ...
# 10  -  Lack of empathy and understanding towards t...
# 11  - Dismissive and rushed communication style.\n...
#
#           Suggested_Improvements_Communication_Expert  \
# 0   - Implement a system for prompt and clear resp...
# 1   - Implement a transparent system for appointme...
# 2   -  Training on patient communication skills an...
# 3   - Implement mandatory customer service trainin...
# 4   - Implement pre-procedure pain management stra...
# 5   - Implement empathy training for all staff mem...
# 6   - Implement mandatory training on patient inte...
# 7   - Implement training programs for staff on eff...
# 8                                                 NaN
# 9   - Implement a system to manage appointment sch...
# 10  - Healthcare providers should actively listen ...
# 11  - Prioritize active listening and patient-cent...
#
#             Final_Recommendation_Communication_Expert  \
# 0   A comprehensive review of the current communic...
# 1   Prioritize patient-centered communication by e...
# 2   Implement mandatory communication training and...
# 3   Invest in communication skills training for st...
# 4   Improve communication protocols by prioritizin...
# 5   A comprehensive review of the communication st...
# 6   A comprehensive review of patient communicatio...
# 7   A comprehensive review and overhaul of current...
# 8   This situation requires immediate intervention...
# 9   Prioritize improving communication and organiz...
# 10  Implement mandatory training on effective comm...
# 11  Implement mandatory training on effective comm...
#
#                        Key_Issues_Manager_and_Advisor  \
# 0   - Lack of responsiveness to patient inquiries....
# 1   - Unequal treatment based on insurance status....
# 2   - Unfriendly and unsympathetic behavior toward...
# 3   - Rudeness and dismissiveness from the secreta...
# 4   - Pain management during and after colonoscopy...
# 5   - Lack of empathy and compassion from receptio...
# 6   - Poor communication quality leading to delays...
# 7   - Lack of empathy and compassion from receptio...
# 8                                                 NaN
# 9   - Excessively long wait times leading to patie...
# 10  - Lack of empathy towards patient's concerns, ...
# 11  - Dismissive and rushed communication style.\n...
#
#                   Recommendations_Manager_and_Advisor
# 0   - Implement a system for prompt responses to p...
# 1   - Implement a transparent system for appointme...
# 2   - Mandatory training on patient communication ...
# 3   - Implement mandatory customer service trainin...
# 4   - Implement pre-procedure pain management stra...
# 5   - Implement mandatory training on empathy and ...
# 6   - Implement mandatory training on patient inte...
# 7   - Implement mandatory training programs for al...
# 8                                                 NaN
# 9   - Implement a robust appointment scheduling sy...
# 10  - Implement mandatory training on effective co...
# 11  - Mandate training on effective communication ...

# %%
import pandas as pd

# Definir o caminho para o arquivo CSV
csv_file_path = r'D:/OneDrive - InMotion - Consulting/AI Projects/AI-Clinical-Advisory-Crew/Dashboard/processed_patient_feedback.csv'

# Ler o CSV
df = pd.read_csv(csv_file_path)

# Contar as linhas vazias em cada coluna
empty_counts = df.isnull().sum()

# Contar as linhas não vazias em cada coluna
non_empty_counts = df.notnull().sum()

# Criar um DataFrame com a contagem de linhas vazias e não vazias
counts_df = pd.DataFrame({
    'Column': df.columns,
    'Non_Empty_Count': non_empty_counts,
    'Empty_Count': empty_counts
})

# Exibir a tabela com a contagem de linhas vazias e não vazias

print(counts_df)
# Out:
#                                                                                                Column  \
# Feedback_ID                                                                               Feedback_ID
# Total_execution_time                                                             Total_execution_time
# Patient_Feedback                                                                     Patient_Feedback
# Sentiment_Patient_Experience_Expert                               Sentiment_Patient_Experience_Expert
# Emotional_Intensity_Patient_Experience_Expert           Emotional_Intensity_Patient_Experience_Expert
# Urgency_Level_Patient_Experience_Expert                       Urgency_Level_Patient_Experience_Expert
# Key_Issues_Patient_Experience_Expert                             Key_Issues_Patient_Experience_Expert
# Patient_Journey_Health_IT_Process_Expert                     Patient_Journey_Health_IT_Process_Expert
# Inefficiencies_Healthcare_Process_Health_IT_Pro...  Inefficiencies_Healthcare_Process_Health_IT_Pr...
# Improvement_Suggestions_Healthcare_Process_Heal...  Improvement_Suggestions_Healthcare_Process_Hea...
# Emotional_State_Clinical_Psychologist                           Emotional_State_Clinical_Psychologist
# Support_Strategy_Clinical_Psychologist                         Support_Strategy_Clinical_Psychologist
# Suggested_Approach_Clinical_Psychologist                     Suggested_Approach_Clinical_Psychologist
# Communication_Quality_Communication_Expert                 Communication_Quality_Communication_Expert
# Issues_Identified_Communication_Expert                         Issues_Identified_Communication_Expert
# Suggested_Improvements_Communication_Expert               Suggested_Improvements_Communication_Expert
# Final_Recommendation_Communication_Expert                   Final_Recommendation_Communication_Expert
# Key_Issues_Manager_and_Advisor                                         Key_Issues_Manager_and_Advisor
# Recommendations_Manager_and_Advisor                               Recommendations_Manager_and_Advisor
#
#                                                     Non_Empty_Count  \
# Feedback_ID                                                      12
# Total_execution_time                                             12
# Patient_Feedback                                                 12
# Sentiment_Patient_Experience_Expert                              12
# Emotional_Intensity_Patient_Experience_Expert                    12
# Urgency_Level_Patient_Experience_Expert                          12
# Key_Issues_Patient_Experience_Expert                             11
# Patient_Journey_Health_IT_Process_Expert                          3
# Inefficiencies_Healthcare_Process_Health_IT_Pro...                2
# Improvement_Suggestions_Healthcare_Process_Heal...                4
# Emotional_State_Clinical_Psychologist                            12
# Support_Strategy_Clinical_Psychologist                           12
# Suggested_Approach_Clinical_Psychologist                         11
# Communication_Quality_Communication_Expert                       12
# Issues_Identified_Communication_Expert                           11
# Suggested_Improvements_Communication_Expert                      11
# Final_Recommendation_Communication_Expert                        12
# Key_Issues_Manager_and_Advisor                                   11
# Recommendations_Manager_and_Advisor                              11
#
#                                                     Empty_Count
# Feedback_ID                                                   0
# Total_execution_time                                          0
# Patient_Feedback                                              0
# Sentiment_Patient_Experience_Expert                           0
# Emotional_Intensity_Patient_Experience_Expert                 0
# Urgency_Level_Patient_Experience_Expert                       0
# Key_Issues_Patient_Experience_Expert                          1
# Patient_Journey_Health_IT_Process_Expert                      9
# Inefficiencies_Healthcare_Process_Health_IT_Pro...           10
# Improvement_Suggestions_Healthcare_Process_Heal...            8
# Emotional_State_Clinical_Psychologist                         0
# Support_Strategy_Clinical_Psychologist                        0
# Suggested_Approach_Clinical_Psychologist                      1
# Communication_Quality_Communication_Expert                    0
# Issues_Identified_Communication_Expert                        1
# Suggested_Improvements_Communication_Expert                   1
# Final_Recommendation_Communication_Expert                     0
# Key_Issues_Manager_and_Advisor                                1
# Recommendations_Manager_and_Advisor                           1
