# %%
import pandas as pd

# Definir o caminho para o arquivo CSV
csv_file_path = r'D:/OneDrive - InMotion - Consulting/AI Projects/AI-Clinical-Advisory-Crew/Dashboard/processed_patient_feedback.csv'

# Ler o CSV
df = pd.read_csv(csv_file_path)

# Exibir as primeiras linhas do dataframe para visualizar os dados
df.head(20)
# Out:
#                Feedback_ID       Total_execution_time  \
# 0   report_20240923_182302   3 minutes and 6 seconds.
# 1   report_20240923_183924  3 minutes and 22 seconds.
# 2   report_20240923_184358  3 minutes and 55 seconds.
# 3   report_20240923_184800  3 minutes and 36 seconds.
# 4   report_20240923_185133   3 minutes and 6 seconds.
# 5   report_20240923_185559  3 minutes and 11 seconds.
# 6   report_20240923_185943  3 minutes and 22 seconds.
# 7   report_20240923_190434  4 minutes and 23 seconds.
# 8   report_20240923_190815  3 minutes and 19 seconds.
# 9   report_20240923_191155  3 minutes and 18 seconds.
# 10  report_20240923_191534   3 minutes and 8 seconds.
# 11  report_20240923_191853  2 minutes and 55 seconds.
# 12  report_20240923_192319  3 minutes and 33 seconds.
# 13  report_20240923_192728  3 minutes and 27 seconds.
#
#                                      Patient_Feedback  \
# 0   Gastro Nayle's service is very poor. He listen...
# ...

# %%
import pandas as pd

# Definir o caminho para o arquivo CSV
csv_file_path = r'D:/OneDrive - InMotion - Consulting/AI Projects/AI-Clinical-Advisory-Crew/Dashboard/processed_patient_feedback.csv'

# Ler o CSV
df = pd.read_csv(csv_file_path)

# Exibir as primeiras linhas do dataframe para visualizar os dados
df.head(20)
# Out:
#                Feedback_ID       Total_execution_time  \
# 0   report_20240923_182302   3 minutes and 6 seconds.
# 1   report_20240923_183924  3 minutes and 22 seconds.
# 2   report_20240923_184358  3 minutes and 55 seconds.
# 3   report_20240923_184800  3 minutes and 36 seconds.
# 4   report_20240923_185133   3 minutes and 6 seconds.
# 5   report_20240923_185559  3 minutes and 11 seconds.
# 6   report_20240923_185943  3 minutes and 22 seconds.
# 7   report_20240923_190434  4 minutes and 23 seconds.
# 8   report_20240923_190815  3 minutes and 19 seconds.
# 9   report_20240923_191155  3 minutes and 18 seconds.
# 10  report_20240923_191534   3 minutes and 8 seconds.
# 11  report_20240923_191853  2 minutes and 55 seconds.
# 12  report_20240923_192319  3 minutes and 33 seconds.
# 13  report_20240923_192728  3 minutes and 27 seconds.
#
#                                      Patient_Feedback  \
# 0   Gastro Nayle's service is very poor. He listen...
# ...
